# %% [markdown]
# # JSON and APIs
#
# _September 22, 2020_
#
# Agenda today:
# - Introduction to API and Remote Server Model
# - Getting data through an API: Case study with YELP API

# %%
import pandas as pd
import numpy as np
import sqlite3
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %% [markdown]
# ## Part I. APIs and Remote Server Model
# API stands for Application Programming Interface. At some point or the other, large companies would build API for their products for their clients or internal use. It allows the company's application to communicate with another application. But what _exactly_ is an API?
#
# #### Remote server
# When we think about the world of Web, we can think of it as a collection of _servers_. And servers are nothing but huge computers that store a huge amount of data from users and are optimized to process requests. For example, when you type in www.facebook.com, your browser sends a _request_ to the Facebook server, and gets a response from the server, thus interpreting the code and displaying your homepage.
#
# In this case, your browser is the _client_, and Facebook’s server is an API. To put it broadly, whenever you visit a website, you are interacting with its API. However, an API isn’t the same as the remote server — rather it is the part of the server that receives __requests__ and sends __responses__.
#
# <img src='status-code.png' width = 500>

# %% [markdown]
# ## Part II. Getting Data Through APIs
#
# The `get()` method send a request to YELP's API, and stored information in a variable called `request`. Next, let's see if it's successful.

# %% [markdown]
# #### YELP API
# Sometimes you need _authentication_ to get data from a service in additional to just sending a `GET()` request. Yelp API is a perfect example.
#
# You will need to go to the YELP's developer's [website](https://www.yelp.com/developers/v3/manage_app) and request for a client ID and API key, which function like a key into a house of data.
#
# <img src='yelp.png' width = 500>

# %%
# lets try to get some data from yelp!
url = 'https://api.yelp.com/v3/businesses/search'
response = requests.get(url)

# %%
# check the status code
response.status_code

# what happened here?

# %%
# now we are ready to get our data 

# usually, services would limit you to a certain amount of API calls. This varies from service
# to service, so you have to watch out to it 

MY_API_KEY = "tr8YVx0XPDpjimn3j1StYTs34ocDudKknopWV3783BfalgcJXjWNlx96ePp1ORLf0_o5KO4YHLzsgnlzHnyIIyRCYqKa70ESFZTXDggTYAAUKx7qrcN50Llk2BZqX3Yx"


term = 'Sandwiches'
location = 'East Village'
SEARCH_LIMIT = 30

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(MY_API_KEY),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
# examine the response object

print(response)
# Out:
# <Response [200]>

# %%
# how are we going to parse the response.text object?

print(response.text)
# Out:
# {"businesses": [{"id": "pWywDImlX0n_XKPNg0Bizg", "alias": "sunny-and-annies-new-york", "name": "Sunny and Annie's", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/R2onHYbQdBM1oVjWRZ900w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sunny-and-annies-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA", "review_count": 485, "categories": [{"alias": "sandwiches", "title": "Sandwiches"}, {"alias": "delis", "title": "Delis"}, {"alias": "grocery", "title": "Grocery"}], "rating": 4.5, "coordinates": {"latitude": 40.724653, "longitude": -73.981702}, "transactions": [], "price": "$", "location": {"address1": "94 Ave B", "address2": null, "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["94 Ave B", "New York, NY 10003"]}, "phone": "+12126773131", "display_phone": "(212) 677-3131", "distance": 218.46104318870601}, {"id": "8M_0cxAChoXl7Ls9YkWJlg", "alias": "xe-may-sandwich-shop-new-york", "name": "Xe May Sandwich Shop", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/u07WeKmygCmLFBrXff4k_Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/xe-may-sandwich-shop-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA", "review_count": 626, "categories": [{"alias": "sandwiches", "title": "Sandwiches"}, {"alias": "vietnamese", "title": "Vietnamese"}, {"alias": "salad", "title": "Salad"}], "rating": 4.5, "coordinates": {"latitude": 40.7272, "longitude": -73.98493}, "transactions": ["delivery", "pickup"], "price": "$", "location": {"address1": "96 Saint Marks Pl", "address2": null, "address3": "", "city": "New York", "zip_code": "10009", "country": "US", "state": "NY", "display_address": ["96 Saint Marks Pl", "New York, NY 10009"]}, "phone": "+12123881688", "display_phone": "(212) 388-1688", "distance": 240.1017476125795}, {"id": "Vix6urWPStcjaS00HSeT3g", "alias": "barnyard-cheese-shop-new-york-4", "name": "Barnyard Cheese Shop", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ewmCsH9-UePVPVIZelMmmg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/barnyard-cheese-shop-new-york-4?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA", "review_count": 152, "categories": [{"alias": "cheese", "title": "Cheese Shops"}, {"alias": "sandwiches", "title": "Sandwiches"}, {"alias": "salad", "title": "Salad"}], "rating": 4.0, "coordinates": {"latitude": 40.727234, "longitude": -73.979772}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "168 Avenue B", "address2": "", "address3": "", "city": "New York", "zip_code": "10009", "country": "US", "state": "NY", "display_address": ["168 Avenue B", "New York, NY 10009"]}, "phone": "+12126742276", "display_phone": "(212) 674-2276", "distance": 216.6154655713498}, {"id": "2zkSs3xE3b30DIywBcyFXg", "alias": "the-dip-new-york-4", "name": "The Dip", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/S6tknKWMeXzuH_06zbNZ3A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-dip-new-york-4?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA", "review_count": 31, "categories": [{"alias": "sandwiches", "title": "Sandwiches"}], "rating": 5.0, "coordinates": {"latitude": 40.7280706083, "longitude": -73.9866325837}, "transactions": ["delivery", "pickup"], "location": {"address1": "58 St Marks Pl", "address2": null, "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["58 St Marks Pl", "New York, NY 10003"]}, "phone": "+16465599050", "display_phone": "(646) 559-9050", "distance": 409.54853732004244}, {"id": "gApAxCJBFJ42YYCpiP4elA", "alias": "foxface-new-york", "name": "Foxface", "image ...

# %%
# working with JSON

sandwiches = response.text
sandwiches = json.loads(sandwiches)

# %%
# cleaning and exploring the data
for key in sandwiches.keys():
    print(key)
# Out:
# businesses
# total
# region

# %%
sandwiches['businesses']
# Out:
# [{'id': 'pWywDImlX0n_XKPNg0Bizg',
#   'alias': 'sunny-and-annies-new-york',
#   'name': "Sunny and Annie's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/R2onHYbQdBM1oVjWRZ900w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sunny-and-annies-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 485,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'grocery', 'title': 'Grocery'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.724653, 'longitude': -73.981702},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '94 Ave B',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['94 Ave B', 'New York, NY 10003']},
#   'phone': '+12126773131',
#   'display_phone': '(212) 677-3131',
#   'distance': 218.46104318870601},
#  {'id': '8M_0cxAChoXl7Ls9YkWJlg',
#   'alias': 'xe-may-sandwich-shop-new-york',
#   'name': 'Xe May Sandwich Shop',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u07WeKmygCmLFBrXff4k_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/xe-may-sandwich-shop-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 626,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7272, 'longitude': -73.98493},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '96 Saint Marks Pl',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['96 Saint Marks Pl', 'New York, NY 10009']},
#   'phone': '+12123881688',
#   'display_phone': '(212) 388-1688',
#   'distance': 240.1017476125795},
#  {'id': 'Vix6urWPStcjaS00HSeT3g',
#   'alias': 'barnyard-cheese-shop-new-york-4',
#   'name': 'Barnyard Cheese Shop',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ewmCsH9-UePVPVIZelMmmg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barnyard-cheese-shop-new-york-4?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 152,
#   'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.727234, 'longitude': -73.979772},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '168 Avenue B',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['168 Avenue B', 'New York, NY 10009']},
#   'phone': '+12126742276',
#   'display_phone': '(212) 674-2276',
#   'distance': 216.6154655713498},
#  {'id': '2zkSs3xE3b30DIywBcyFXg',
#   'alias': 'the-dip-new-york-4',
#   'name': 'The Dip',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S6tknKWMeXzuH_06zbNZ3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-dip-new-york-4?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 31,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7280706083, 'longitude': -73.9866325837},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '58 St Marks Pl',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['58 St Marks Pl', 'New York, NY 10003']},
#   'phone': '+16465599050',
#   'display_phone': '(646) 559-9050',
#   'distance': 409.54853732004244},
#  {'id': 'gApAxCJBFJ42YYCpiP4elA',
#   'alias': 'foxface-new-york',
#   'name': 'Foxface',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2RbWrYoDyV3TZAh7p8wQBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/foxface-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 22,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72765, 'longitude': -73.98573},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': "80 Saint Mark's Pl",
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ["80 Saint Mark's Pl", 'New York, NY 10003']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 322.57820917912505},
#  {'id': 'Yg5RYfgQauY4mvY3pixzqA',
#   'alias': 'le-petit-parisien-new-york',
#   'name': 'Le Petit Parisien',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hdewQ7vPpWhxSTzCmX-6fw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-petit-parisien-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 60,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72821, 'longitude': -73.98921},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '32 E 7th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 E 7th St', 'New York, NY 10003']},
#   'phone': '+19172620406',
#   'display_phone': '(917) 262-0406',
#   'distance': 618.7618008140804},
#  {'id': 'Ew3d7Vt18c1MH4_X6ogxQQ',
#   'alias': 'banh-mi-zon-new-york-4',
#   'name': 'Banh Mi Zon',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MmV22bjypsCf_32llkUTpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/banh-mi-zon-new-york-4?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 308,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7256861, 'longitude': -73.9842575},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '443 E 6th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['443 E 6th St', 'New York, NY 10009']},
#   'phone': '+16465246384',
#   'display_phone': '(646) 524-6384',
#   'distance': 200.2327322410642},
#  {'id': 'QEY6X80_WXLmCvpOxphzxA',
#   'alias': 'smør-new-york',
#   'name': 'Smør',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p8aNqMxVJaqyJenP8pjp4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sm%C3%B8r-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 49,
#   'categories': [{'alias': 'scandinavian', 'title': 'Scandinavian'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72927, 'longitude': -73.98153},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '441 E 12th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['441 E 12th St', 'New York, NY 10009']},
#   'phone': '+16464788391',
#   'display_phone': '(646) 478-8391',
#   'distance': 309.8260233185532},
#  {'id': '_Rpp6IgpkE_UuRsmr4iSaA',
#   'alias': 'tinys-giant-sandwich-shop-new-york',
#   'name': "Tiny's Giant Sandwich Shop",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VoKR4EaCRXL-33GvR5Jtiw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tinys-giant-sandwich-shop-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 486,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7195, 'longitude': -73.98699},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '129 Rivington St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['129 Rivington St', 'New York, NY 10002']},
#   'phone': '+12122284919',
#   'display_phone': '(212) 228-4919',
#   'distance': 880.6596533310756},
#  {'id': '6q6WWGaO75PQkpWOQ2zzHQ',
#   'alias': 'parisi-bakery-new-york-4',
#   'name': 'Parisi Bakery',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9P2czBcU6yl8-wgPygmCgQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/parisi-bakery-new-york-4?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 409,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'delis', 'title': 'Delis'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7211836, 'longitude': -73.9954365},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '198 Mott St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['198 Mott St', 'New York, NY 10012']},
#   'phone': '+12122266378',
#   'display_phone': '(212) 226-6378',
#   'distance': 1270.7995627210987},
#  {'id': 'gHdejB1Mx2P5UjAgZ6BT2w',
#   'alias': 'cheeky-sandwiches-new-york',
#   'name': 'Cheeky Sandwiches',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XGGQOLhQIL-Y8Y-CdHeOPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cheeky-sandwiches-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 1188,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7158, 'longitude': -73.99169},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '35 Orchard St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35 Orchard St', 'New York, NY 10002']},
#   'phone': '+16465048132',
#   'display_phone': '(646) 504-8132',
#   'distance': 1444.3567381993744},
#  {'id': '4309N8881V2xz_jI0hUIog',
#   'alias': 'original-nickys-vietnamese-sandwiches-new-york-2',
#   'name': "Original Nicky's Vietnamese Sandwiches",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RV799hX1DA2y0WVijLH2rQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/original-nickys-vietnamese-sandwiches-new-york-2?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 53,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72968, 'longitude': -73.98107},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '209 Avenue A',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['209 Avenue A', 'New York, NY 10009']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 358.94015606227305},
#  {'id': 'n-szxTmEg8UWhiadbvz_Ug',
#   'alias': 'russo-mozzarella-and-pasta-new-york',
#   'name': 'Russo Mozzarella & Pasta',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KamEaZzrDoLCzbZWdHJggg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/russo-mozzarella-and-pasta-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 100,
#   'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729401179008, 'longitude': -73.984412681264},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '344 E 11th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['344 E 11th St', 'New York, NY 10003']},
#   'phone': '+12122547452',
#   'display_phone': '(212) 254-7452',
#   'distance': 365.7819714508777},
#  {'id': 'eJzVEVIHql5Vyi0jNxT0Xg',
#   'alias': 'santa-barbara-deli-manhattan',
#   'name': 'Santa Barbara Deli',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kxpW5jITyW6Z9L-ky6KbaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/santa-barbara-deli-manhattan?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 21,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7282296, 'longitude': -73.9791262},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '551 E 12th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Manhattan',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['551 E 12th St', 'Manhattan, NY 10009']},
#   'phone': '+12122541732',
#   'display_phone': '(212) 254-1732',
#   'distance': 317.0921306006333},
#  {'id': 'ADHX7nBixDPVlq3OXhny0g',
#   'alias': 'faiccos-italian-specialties-new-york',
#   'name': "Faicco's Italian Specialties",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ecEFegMI5jPZbSI2QnndrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/faiccos-italian-specialties-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 531,
#   'categories': [{'alias': 'meats', 'title': 'Meat Shops'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73113, 'longitude': -74.00306},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '260 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['260 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12122431974',
#   'display_phone': '(212) 243-1974',
#   'distance': 1832.5531672275852},
#  {'id': 'PpxJsItHTF6sDAK6XnDJ9w',
#   'alias': 'bite-new-york-3',
#   'name': 'Bite',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L03vdeCPEklcL8zPl7-mqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bite-new-york-3?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 618,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.733163, 'longitude': -73.986158},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '211 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['211 E 14th St', 'New York, NY 10003']},
#   'phone': '+12126773123',
#   'display_phone': '(212) 677-3123',
#   'distance': 805.2019876058908},
#  {'id': 'gjJiJ5yHqiEe3sFn_v-5JA',
#   'alias': 'c-and-b-new-york',
#   'name': 'C&B',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TPJvZ756ABhk8_0X6bsOkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/c-and-b-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 210,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7252271901335,
#    'longitude': -73.9816302970189},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '178 E 7th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['178 E 7th St', 'New York, NY 10009']},
#   'phone': '+12126742985',
#   'display_phone': '(212) 674-2985',
#   'distance': 157.1519015119395},
#  {'id': 'N5UY113nNpeKdLPv0cbMjQ',
#   'alias': 'the-wild-son-new-york',
#   'name': 'The Wild Son',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bKbzwnDOl26D3aVzh-lj0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-wild-son-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 489,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.727424, 'longitude': -73.985201},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '132 First Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['132 First Ave', 'New York, NY 10009']},
#   'phone': '+12127277900',
#   'display_phone': '(212) 727-7900',
#   'distance': 265.31248699864693},
#  {'id': 'nD7Hcq5aaCASbWzc0-Sg3A',
#   'alias': 'bobwhite-counter-new-york-7',
#   'name': 'Bobwhite Counter',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/udg_KBFV9l98jIyqSborPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bobwhite-counter-new-york-7?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 801,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72365, 'longitude': -73.97899},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '94 Ave C',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['94 Ave C', 'New York, NY 10009']},
#   'phone': '+12122282972',
#   'display_phone': '(212) 228-2972',
#   'distance': 425.23404142317656},
#  {'id': 'a7BC1doUjNDqrqTaAMmfZg',
#   'alias': 'bite-new-york',
#   'name': 'Bite',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TwZI7h0HzbdECV7Tv7WQWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bite-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 268,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7257318645125,
#    'longitude': -73.9946338116395},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '335 Lafayette St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['335 Lafayette St', 'New York, NY 10012']},
#   'phone': '+12124310301',
#   'display_phone': '(212) 431-0301',
#   'distance': 1052.7011381254454},
#  {'id': '5K-AyByoRLKW5XMxOSkNTA',
#   'alias': 'court-street-grocers-laguardia-place-new-york',
#   'name': 'Court Street Grocers LaGuardia Place',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfSNhyinaLnk4Flyzz7rQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/court-street-grocers-laguardia-place-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 112,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72889, 'longitude': -73.99861},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '540 Laguardia Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['540 Laguardia Pl', 'New York, NY 10012']},
#   'phone': '+12127779292',
#   'display_phone': '(212) 777-9292',
#   'distance': 1410.0907927200294},
#  {'id': 'TWkWL9Jeb-tMA3PxiZsqkg',
#   'alias': 'sassys-specialty-sandwiches-brooklyn',
#   'name': "Sassy's Specialty Sandwiches",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jc0kQB7kYBxY_TMuvYwd6w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sassys-specialty-sandwiches-brooklyn?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 37,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71051, 'longitude': -73.95881},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '233 S 4th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['233 S 4th St', 'Brooklyn, NY 11211']},
#   'phone': '+17183847515',
#   'display_phone': '(718) 384-7515',
#   'distance': 2665.720565467691},
#  {'id': '6OSf-XAdH9z-jLiXxTPZKg',
#   'alias': 'the-original-sandwich-shoppe-of-new-york-new-york',
#   'name': 'The Original Sandwich Shoppe of New York',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HQCcsYQNotkBxeKtEbvksw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-original-sandwich-shoppe-of-new-york-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 191,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73594, 'longitude': -74.00057},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '58 Greenwich Ave',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['58 Greenwich Ave', 'Ste A', 'New York, NY 10011']},
#   'phone': '+12122552237',
#   'display_phone': '(212) 255-2237',
#   'distance': 1867.0089017000405},
#  {'id': 'ml5hBBDsEILy9WsTQyyV-Q',
#   'alias': 'b-cup-café-new-york-5',
#   'name': 'B Cup Café',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Ow6irDxjC5gOazKhJ2rAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/b-cup-caf%C3%A9-new-york-5?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 375,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.728708, 'longitude': -73.978827},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '212 Ave B',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['212 Ave B', 'New York, NY 10009']},
#   'phone': '+12122284808',
#   'display_phone': '(212) 228-4808',
#   'distance': 370.5150933622537},
#  {'id': 'VrCCr45dhN-RRM107iptdg',
#   'alias': 'russ-and-daughters-new-york',
#   'name': 'Russ & Daughters',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EN-MJ-kuk_-ihX1_DKHgFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/russ-and-daughters-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 2237,
#   'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#    {'alias': 'smokehouse', 'title': 'Smokehouse'},
#    {'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722589, 'longitude': -73.9882828294139},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '179 E Houston St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['179 E Houston St', 'New York, NY 10002']},
#   'phone': '+12124754880',
#   'display_phone': '(212) 475-4880',
#   'distance': 678.2185393150921},
#  {'id': '1TZ9CzGDGdAGCADjoYaliA',
#   'alias': 'otaku-katsu-new-york-2',
#   'name': 'Otaku Katsu',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sx0fx20vkS5ZT51uRw3Ibw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/otaku-katsu-new-york-2?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 66,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.719384, 'longitude': -73.986529},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '137 Rivington St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['137 Rivington St', 'New York, NY 10002']},
#   'phone': '+19173883924',
#   'display_phone': '(917) 388-3924',
#   'distance': 879.2118449526301},
#  {'id': '9zlJ7CsIe0PpFplZepXaSQ',
#   'alias': 'smartwich-new-york',
#   'name': 'SMARTWICH',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sINO5WNLR_sBNOILGTj4mg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/smartwich-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 10,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.73026, 'longitude': -73.989},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '31 3rd Ave',
#    'address2': None,
#    'address3': 'The Bean Coffee Place',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['31 3rd Ave',
#     'The Bean Coffee Place',
#     'New York, NY 10003']},
#   'phone': '+19172614364',
#   'display_phone': '(917) 261-4364',
#   'distance': 698.2299746125743},
#  {'id': 't4M1VX4n34eEgUWMJ7cgKw',
#   'alias': 'daily-provisions-new-york',
#   'name': 'Daily Provisions',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hTujUcXLFmDNgc_dTi3xAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/daily-provisions-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 406,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73768, 'longitude': -73.9876685},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '103 E 19th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['103 E 19th St', 'New York, NY 10003']},
#   'phone': '+12124881505',
#   'display_phone': '(212) 488-1505',
#   'distance': 1313.2005915185864},
#  {'id': 'dE_NbpR8bFmZVKNSPFZfUA',
#   'alias': 'tramezzini-nyc-new-york',
#   'name': 'Tramezzini NYC',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l5iVSYY6ham-PbuYkxqYiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tramezzini-nyc-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 111,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7211848351606, 'longitude': -73.983472726423},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '309 E Houston',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['309 E Houston', 'New York, NY 10002']},
#   'phone': '+19293405133',
#   'display_phone': '(929) 340-5133',
#   'distance': 609.0206153996284},
#  {'id': 'ipAsHykRvgJzpx5hD8vTJw',
#   'alias': 'tokuyama-salon-café-new-york',
#   'name': 'Tokuyama Salon Café',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1wtAhlzaf5Mltj2Elz2YIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tokuyama-salon-caf%C3%A9-new-york?adjust_creative=nNUlMrpIeq6gBR9V9Ab1SA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nNUlMrpIeq6gBR9V9Ab1SA',
#   'review_count': 35,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72399, 'longitude': -73.9802},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '627 E 6th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['627 E 6th St', 'New York, NY 10009']},
#   'phone': '+12123881276',
#   'display_phone': '(212) 388-1276',
#   'distance': 330.6182505334082}]

# %%
# turn the relevant dataset into a dataframe

sandwiches_df = pd.DataFrame.from_dict(sandwiches['businesses'])
sandwiches_df.head()
# Out:
#                        id                            alias  \
# 0  pWywDImlX0n_XKPNg0Bizg        sunny-and-annies-new-york
# 1  8M_0cxAChoXl7Ls9YkWJlg    xe-may-sandwich-shop-new-york
# 2  Vix6urWPStcjaS00HSeT3g  barnyard-cheese-shop-new-york-4
# 3  2zkSs3xE3b30DIywBcyFXg               the-dip-new-york-4
# 4  gApAxCJBFJ42YYCpiP4elA                 foxface-new-york
#
#                    name                                          image_url  \
# 0     Sunny and Annie's  https://s3-media4.fl.yelpcdn.com/bphoto/R2onHY...
# 1  Xe May Sandwich Shop  https://s3-media3.fl.yelpcdn.com/bphoto/u07WeK...
# 2  Barnyard Cheese Shop  https://s3-media3.fl.yelpcdn.com/bphoto/ewmCsH...
# 3               The Dip  https://s3-media2.fl.yelpcdn.com/bphoto/S6tknK...
# 4               Foxface  https://s3-media3.fl.yelpcdn.com/bphoto/2RbWrY...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/sunny-and-annies-new-...           485
# 1      False  https://www.yelp.com/biz/xe-may-sandwich-shop-...           626
# 2      False  https://www.yelp.com/biz/barnyard-cheese-shop-...           152
# 3      False  https://www.yelp.com/biz/the-dip-new-york-4?ad...            31
# 4      False  https://www.yelp.com/biz/foxface-new-york?adju...            22
#
#                                           categories  rating  \
# 0  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 1  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 2  [{'alias': 'cheese', 'title': 'Cheese Shops'},...     4.0
# 3   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     5.0
# 4   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.5
#
#                                          coordinates        transactions  \
# 0   {'latitude': 40.724653, 'longitude': -73.981702}                  []
# 1      {'latitude': 40.7272, 'longitude': -73.98493}  [delivery, pickup]
# 2   {'latitude': 40.727234, 'longitude': -73.979772}  [delivery, pickup]
# 3  {'latitude': 40.7280706083, 'longitude': -73.9...  [delivery, pickup]
# 4     {'latitude': 40.72765, 'longitude': -73.98573}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0     $  {'address1': '94 Ave B', 'address2': None, 'ad...  +12126773131
# 1     $  {'address1': '96 Saint Marks Pl', 'address2': ...  +12123881688
# 2    $$  {'address1': '168 Avenue B', 'address2': '', '...  +12126742276
# 3   NaN  {'address1': '58 St Marks Pl', 'address2': Non...  +16465599050
# 4    $$  {'address1': '80 Saint Mark's Pl', 'address2':...
#
#     display_phone    distance
# 0  (212) 677-3131  218.461043
# 1  (212) 388-1688  240.101748
# 2  (212) 674-2276  216.615466
# 3  (646) 559-9050  409.548537
# 4                  322.578209

# %%
print(sandwiches_df.iloc[0, 5])
# Out:
# [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'grocery', 'title': 'Grocery'}]

# %%
# you can do some analysis and visualization from here on! 
# visualize the review count - what's the appropriate plot?



# sandwiches_df['latitude'] = sandwiches_df['coordinates'].map(lambda x: x['latitude'])
# sandwiches_df['longitude'] = sandwiches_df['coordinates'].map(lambda x: x['longitude'])

# sandwiches_df.set_index(sandwiches_df['id'], inplace = True)
# sandwiches_df.drop(['id'], axis = 1, inplace = True)
# sandwiches_df.drop(['image_url'], axis = 1, inplace = True)
# sandwiches_df.drop(['coordinates'], axis = 1, inplace = True)
# sandwiches_df.dropna(inplace = True)
# sandwiches_df.replace('', np.nan, inplace = True)
# sandwiches_df['price'] = sandwiches_df['price'].map(lambda x: len(x))


sandwiches_df.head()
# Out:
#                                                   alias                  name  \
# id
# pWywDImlX0n_XKPNg0Bizg        sunny-and-annies-new-york     Sunny and Annie's
# 8M_0cxAChoXl7Ls9YkWJlg    xe-may-sandwich-shop-new-york  Xe May Sandwich Shop
# Vix6urWPStcjaS00HSeT3g  barnyard-cheese-shop-new-york-4  Barnyard Cheese Shop
# Yg5RYfgQauY4mvY3pixzqA       le-petit-parisien-new-york     Le Petit Parisien
# Ew3d7Vt18c1MH4_X6ogxQQ           banh-mi-zon-new-york-4           Banh Mi Zon
#
#                         is_closed  \
# id
# pWywDImlX0n_XKPNg0Bizg      False
# 8M_0cxAChoXl7Ls9YkWJlg      False
# Vix6urWPStcjaS00HSeT3g      False
# Yg5RYfgQauY4mvY3pixzqA      False
# Ew3d7Vt18c1MH4_X6ogxQQ      False
#
#                                                                       url  \
# id
# pWywDImlX0n_XKPNg0Bizg  https://www.yelp.com/biz/sunny-and-annies-new-...
# 8M_0cxAChoXl7Ls9YkWJlg  https://www.yelp.com/biz/xe-may-sandwich-shop-...
# Vix6urWPStcjaS00HSeT3g  https://www.yelp.com/biz/barnyard-cheese-shop-...
# Yg5RYfgQauY4mvY3pixzqA  https://www.yelp.com/biz/le-petit-parisien-new...
# Ew3d7Vt18c1MH4_X6ogxQQ  https://www.yelp.com/biz/banh-mi-zon-new-york-...
#
#                         review_count  \
# id
# pWywDImlX0n_XKPNg0Bizg           485
# 8M_0cxAChoXl7Ls9YkWJlg           626
# Vix6urWPStcjaS00HSeT3g           152
# Yg5RYfgQauY4mvY3pixzqA            60
# Ew3d7Vt18c1MH4_X6ogxQQ           308
#
#                                                                categories  \
# id
# pWywDImlX0n_XKPNg0Bizg  [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 8M_0cxAChoXl7Ls9YkWJlg  [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# Vix6urWPStcjaS00HSeT3g  [{'alias': 'cheese', 'title': 'Cheese Shops'},...
# Yg5RYfgQauY4mvY3pixzqA  [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# Ew3d7Vt18c1MH4_X6ogxQQ  [{'alias': 'vietnamese', 'title': 'Vietnamese'...
#
#                         rating        transactions  price  \
# id
# pWywDImlX0n_XKPNg0Bizg     4.5                  []      1
# 8M_0cxAChoXl7Ls9YkWJlg     4.5  [delivery, pickup]      1
# Vix6urWPStcjaS00HSeT3g     4.0  [delivery, pickup]      2
# Yg5RYfgQauY4mvY3pixzqA     4.5  [delivery, pickup]      2
# Ew3d7Vt18c1MH4_X6ogxQQ     4.5  [delivery, pickup]      1
#
#                                                                  location  \
# id
# pWywDImlX0n_XKPNg0Bizg  {'address1': '94 Ave B', 'address2': None, 'ad...
# 8M_0cxAChoXl7Ls9YkWJlg  {'address1': '96 Saint Marks Pl', 'address2': ...
# Vix6urWPStcjaS00HSeT3g  {'address1': '168 Avenue B', 'address2': '', '...
# Yg5RYfgQauY4mvY3pixzqA  {'address1': '32 E 7th St', 'address2': None, ...
# Ew3d7Vt18c1MH4_X6ogxQQ  {'address1': '443 E 6th St', 'address2': '', '...
#
#                                phone   display_phone    distance   latitude  \
# id
# pWywDImlX0n_XKPNg0Bizg  +12126773131  (212) 677-3131  218.461043  40.724653
# 8M_0cxAChoXl7Ls9YkWJlg  +12123881688  (212) 388-1688  240.101748  40.727200
# Vix6urWPStcjaS00HSeT3g  +12126742276  (212) 674-2276  216.615466  40.727234
# Yg5RYfgQauY4mvY3pixzqA  +19172620406  (917) 262-0406  618.761801  40.728210
# Ew3d7Vt18c1MH4_X6ogxQQ  +16465246384  (646) 524-6384  200.232732  40.725686
#
#                         longitude
# id
# pWywDImlX0n_XKPNg0Bizg -73.981702
# 8M_0cxAChoXl7Ls9YkWJlg -73.984930
# Vix6urWPStcjaS00HSeT3g -73.979772
# Yg5RYfgQauY4mvY3pixzqA -73.989210
# Ew3d7Vt18c1MH4_X6ogxQQ -73.984257

# %%
# query the name of the axe throwing place with the highest review
# sandwiches_df.plot(x = 'name', y = 'review_count', kind = 'bar');

chart = sns.barplot(x = sandwiches_df['name'], y = sandwiches_df['review_count'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right');

# %%
sandwiches_df[sandwiches_df['name'] == 'Bite']
len(sandwiches_df.iloc[3, 10])
# Out:
# 0

# %%
# migrate the cleaned data into a sql db

conn = sqlite3.connect('sandwiches.db')
cur = conn.cursor()

# %%
# sandwiches_df.rename(columns = {'rating': 'rating'}, inplace = True)
sandwiches_df.to_sql('sandwiches', con = conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-cdbf9d11ff53> in <module>()
#       1 # sandwiches_df.rename(columns = {'rating': 'rating'}, inplace = True)
# ----> 2 sandwiches_df.to_sql('sandwiches', con = conn)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1747             dtype=dtype,
#    1748         )
# -> 1749         table.create()
#    1750         table.insert(chunksize, method)
#    1751
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/sql.py in create(self)
#     642             if self.if_exists == "fail":
#     643                 raise ValueError(
# --> 644                     "Table '{name}' already exists.".format(name=self.name)
#     645                 )
#     646             elif self.if_exists == "replace":
#
# ValueError: Table 'sandwiches' already exists.

# %%
# can you do some other queries using sql/pandas?

query1 = """DROP TABLE sandwiches"""
cur.execute(query1).fetchall()
# Out:
# []

# %% [markdown]
# #### Resources
# - [Getting Data from Reddit API](https://www.storybench.org/how-to-scrape-reddit-with-python/)
# - [Twitch API](https://dev.twitch.tv/docs)
